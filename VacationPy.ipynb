# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output/cities.csv")

# Display sample data
city_data_df
# Out:
#      City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 0          0            iqaluit  63.7506  -68.5145     -3.15        73
# 1          1  port-aux-francais -49.3500   70.2167      4.32        66
# 2          2             bethel  41.3712  -73.4140      9.47        63
# 3          3              tiksi  71.6872  128.8694    -10.00        80
# 4          4            aasiaat  68.7098  -52.8699     -4.43        99
# ..       ...                ...      ...       ...       ...       ...
# 559      559    horishni plavni  49.0097   33.6455     10.51        70
# 560      560               bodo  67.2800   14.4050      2.10        80
# 561      561    richland center  43.3347  -90.3868     11.90        82
# 562      562          micheweni  -4.9667   39.8333     26.35        88
# 563      563             cannes  43.5500    7.0167     10.05        89
#
#      Cloudiness  Wind Speed Country        Date
# 0           100        0.00      CA  1713929412
# 1            53       14.40      TF  1713929286
# 2             0        2.68      US  1713929470
# 3            98        3.75      RU  1713929295
# 4            86        3.00      GL  1713929471
# ..          ...         ...     ...         ...
# 559         100        5.82      UA  1713929612
# 560          75        1.54      NO  1713929601
# 561          20        5.19      US  1713929538
# 562          99        5.50      TZ  1713929613
# 563           0        2.06      FR  1713929613
#
# [564 rows x 10 columns]

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
import hvplot.pandas
import pandas as pd

# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# %%
# %%capture --no-display

# Configure the map plot
map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "EsriNatGeo",
    frame_width = 700,
    frame_height = 500,
    size = "Humidity",
    scale = 0.25,
    color = "City"
)


# Display the map plot
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal_cities = city_data_df.loc[(city_data_df['Max Temp'] <= 25) & 
                                (city_data_df['Max Temp'] >= 20) & 
                                (city_data_df['Humidity'] < 60), :]

# Drop any rows with null values
ideal_cities = ideal_cities.dropna()

# Display sample data
ideal_cities
# Out:
#      City_ID           City      Lat       Lng  Max Temp  Humidity  \
# 15        15         nahrin  36.0649   69.1334     20.98        37
# 16        16        erenhot  43.6475  111.9767     22.83        11
# 49        49         beyneu  45.3167   55.2000     20.35        44
# 119      119       jiujiang  29.7333  115.9833     24.22        57
# 141      141      xilin hot  43.9667  116.0333     21.10        12
# 142      142         cayeli  41.0923   40.7292     20.91        52
# 162      162        shalqar  47.8333   59.6000     21.33        35
# 185      185      ulladulla -35.3500  150.4667     24.32        52
# 206      206      turkestan  43.3333   68.2500     23.92        39
# 209      209    saint-louis  16.3333  -15.0000     22.80        47
# 212      212          hotan  37.0997   79.9269     23.71        16
# 272      272   christchurch -43.5333  172.6333     23.08        37
# 310      310        reggane  26.7158    0.1714     24.91        17
# 324      324  alice springs -23.7000  133.8833     22.75        46
# 397      397            chu  43.5983   73.7614     20.55        48
# 414      414   umm kaddadah  13.6017   26.6876     24.60         9
# 415      415        kantagi  43.5264   68.5775     23.20        35
# 433      433       kingaroy -26.5333  151.8333     22.30        58
# 467      467         tirmiz  37.2242   67.2783     22.05        56
# 501      501        akjoujt  19.6969  -14.4164     24.79        27
# 508      508       yulinshi  38.2906  109.7494     21.42        19
# 511      511        ballina -28.8667  153.5667     24.88        53
# 516      516           dali  25.7000  100.1833     23.99        30
# 526      526        juegang  32.3174  121.1855     21.30        41
#
#      Cloudiness  Wind Speed Country        Date
# 15            1        0.93      AF  1713929473
# 16            3       13.15      CN  1713929473
# 49            1        9.32      KZ  1713929481
# 119         100        3.29      CN  1713929506
# 141           6        9.39      CN  1713929514
# 142          76        2.57      TR  1713929515
# 162          58        0.88      KZ  1713929521
# 185          37        7.16      AU  1713929526
# 206           0        4.85      KZ  1713929531
# 209           2        4.60      SN  1713929532
# 212          92        6.98      CN  1713929532
# 272          10        7.20      NZ  1713929381
# 310          51        4.40      DZ  1713929554
# 324          39        7.20      AU  1713929557
# 397          20        4.98      KZ  1713929573
# 414          12        5.19      SD  1713929578
# 415           3        1.44      KZ  1713929578
# 433          36        0.89      AU  1713929582
# 467           0        4.12      UZ  1713929590
# 501           0        3.25      MR  1713929598
# 508           0        3.54      CN  1713929600
# 511          94        0.96      AU  1713929600
# 516          10        4.36      CN  1713929601
# 526          98        4.06      CN  1713929604

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_cities[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()

# Add an empty column, "Hotel Name," to the DataFrame
hotel_df['Hotel Name'] = ''

# Display sample data
hotel_df
# Out:
#               City Country      Lat       Lng  Humidity Hotel Name
# 15          nahrin      AF  36.0649   69.1334        37
# 16         erenhot      CN  43.6475  111.9767        11
# 49          beyneu      KZ  45.3167   55.2000        44
# 119       jiujiang      CN  29.7333  115.9833        57
# 141      xilin hot      CN  43.9667  116.0333        12
# 142         cayeli      TR  41.0923   40.7292        52
# 162        shalqar      KZ  47.8333   59.6000        35
# 185      ulladulla      AU -35.3500  150.4667        52
# 206      turkestan      KZ  43.3333   68.2500        39
# 209    saint-louis      SN  16.3333  -15.0000        47
# 212          hotan      CN  37.0997   79.9269        16
# 272   christchurch      NZ -43.5333  172.6333        37
# 310        reggane      DZ  26.7158    0.1714        17
# 324  alice springs      AU -23.7000  133.8833        46
# 397            chu      KZ  43.5983   73.7614        48
# 414   umm kaddadah      SD  13.6017   26.6876         9
# 415        kantagi      KZ  43.5264   68.5775        35
# 433       kingaroy      AU -26.5333  151.8333        58
# 467         tirmiz      UZ  37.2242   67.2783        56
# 501        akjoujt      MR  19.6969  -14.4164        27
# 508       yulinshi      CN  38.2906  109.7494        19
# 511        ballina      AU -28.8667  153.5667        53
# 516           dali      CN  25.7000  100.1833        30
# 526        juegang      CN  32.3174  121.1855        41

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 100000
params = {
    'radius': radius,
    'categories': 'accommodation',
    'apiKey': geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row['Lat']
    lng = row['Lng']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{radius}@{lng},{lat}"
    params["bias"] = f"proximity:{lng},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)

    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# nahrin - nearest hotel: No hotel found
# erenhot - nearest hotel: No hotel found
# beyneu - nearest hotel: No hotel found
# jiujiang - nearest hotel: No hotel found
# xilin hot - nearest hotel: No hotel found
# cayeli - nearest hotel: No hotel found
# shalqar - nearest hotel: No hotel found
# ulladulla - nearest hotel: No hotel found
# turkestan - nearest hotel: No hotel found
# saint-louis - nearest hotel: No hotel found
# hotan - nearest hotel: No hotel found
# christchurch - nearest hotel: No hotel found
# reggane - nearest hotel: No hotel found
# alice springs - nearest hotel: No hotel found
# chu - nearest hotel: No hotel found
# umm kaddadah - nearest hotel: No hotel found
# kantagi - nearest hotel: No hotel found
# kingaroy - nearest hotel: No hotel found
# tirmiz - nearest hotel: No hotel found
# akjoujt - nearest hotel: No hotel found
# yulinshi - nearest hotel: No hotel found
# ballina - nearest hotel: No hotel found
# dali - nearest hotel: No hotel found
# juegang - nearest hotel: No hotel found
#               City Country      Lat       Lng  Humidity      Hotel Name
# 15          nahrin      AF  36.0649   69.1334        37  No hotel found
# 16         erenhot      CN  43.6475  111.9767        11  No hotel found
# 49          beyneu      KZ  45.3167   55.2000        44  No hotel found
# 119       jiujiang      CN  29.7333  115.9833        57  No hotel found
# 141      xilin hot      CN  43.9667  116.0333        12  No hotel found
# 142         cayeli      TR  41.0923   40.7292        52  No hotel found
# 162        shalqar      KZ  47.8333   59.6000        35  No hotel found
# 185      ulladulla      AU -35.3500  150.4667        52  No hotel found
# 206      turkestan      KZ  43.3333   68.2500        39  No hotel found
# 209    saint-louis      SN  16.3333  -15.0000        47  No hotel found
# 212          hotan      CN  37.0997   79.9269        16  No hotel found
# 272   christchurch      NZ -43.5333  172.6333        37  No hotel found
# 310        reggane      DZ  26.7158    0.1714        17  No hotel found
# 324  alice springs      AU -23.7000  133.8833        46  No hotel found
# 397            chu      KZ  43.5983   73.7614        48  No hotel found
# 414   umm kaddadah      SD  13.6017   26.6876         9  No hotel found
# 415        kantagi      KZ  43.5264   68.5775        35  No hotel found
# 433       kingaroy      AU -26.5333  151.8333        58  No hotel found
# 467         tirmiz      UZ  37.2242   67.2783        56  No hotel found
# 501        akjoujt      MR  19.6969  -14.4164        27  No hotel found
# 508       yulinshi      CN  38.2906  109.7494        19  No hotel found
# 511        ballina      AU -28.8667  153.5667        53  No hotel found
# 516           dali      CN  25.7000  100.1833        30  No hotel found
# 526        juegang      CN  32.3174  121.1855        41  No hotel found

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_1 = hotel_df.hvplot.points(
    'Lng',
    'Lat',
    geo=True,
    tiles='EsriNatGeo',
    frame_width=700,
    frame_height=500,
    size='Humidity',
    scale=0.25,
    color='City',
    hover_cols=['City', 'Hotel Name']  # Add hover information for city and hotel name
)

# Display the map plot
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name)
